# %% [markdown]
# Weekly Quote - JSON

# %% [markdown]
# The chave_api is used to pull my API private key (alphavantage), at the time of execution, the key itself must be included.

# %%
from chave import chave_api

import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB4.SAO&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)

# %% [markdown]
# Weekly Quote - CSV

# %%
import pandas as pd
from io import StringIO

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB4.SAO&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)

# %%
Quote

# %%
acoes = ['ITUB4', 'ABEV3', 'BBAS3']

compilada = pd.DataFrame()

for acao in acoes:
    url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={acao}.SAO&apikey={chave_api}&datatype=csv'
    r = requests.get(url)
    tabela = pd.read_csv(StringIO(r.text))
    lista_tabelas = [compilada, tabela]
    compilada = pd.concat(lista_tabelas)
    
display(compilada)
# Out:
#       symbol   open   high    low  price    volume   latestDay  previousClose  \
# 0  ITUB4.SAO  26.70  27.04  26.62  26.75  24457700  2022-09-09          26.54
# 0  ABEV3.SAO  15.50  15.76  15.48  15.72  13422600  2022-09-09          15.50
# 0  BBAS3.SAO  39.93  40.90  39.82  40.55  22529800  2022-09-09          39.46
#
#    change changePercent
# 0    0.21       0.7913%
# 0    0.22       1.4194%
# 0    1.09       2.7623%

# %% [markdown]
# Search assets by company name

# %%
url = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=amazon&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#        symbol                    name    type            region marketOpen  \
# 0        AMZN          Amazon.com Inc  Equity     United States      09:30
# 1     AMZ.DEX          Amazon.com Inc  Equity             XETRA      08:00
# 2     AMZ.FRK          Amazon.com Inc  Equity         Frankfurt      08:00
# 3  AMZO34.SAO          Amazon.com Inc  Equity  Brazil/Sao Paolo      10:00
# 4    0R1O.LON         Amazon.com Inc.  Equity    United Kingdom      08:00
# 5        AZFL  Amazonas Florestal Ltd  Equity     United States      09:30
#
#   marketClose timezone currency  matchScore
# 0       16:00   UTC-04      USD      0.8000
# 1       20:00   UTC+02      EUR      0.6000
# 2       20:00   UTC+02      EUR      0.6000
# 3       17:30   UTC-03      BRL      0.6000
# 4       16:30   UTC+01      USD      0.5714
# 5       16:00   UTC-04      USD      0.4286

# %% [markdown]
# Results

# %%
url = f'https://www.alphavantage.co/query?function=EARNINGS&symbol=AMZN&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {
reportedDate': '2021-04-29', 'reportedEPS': '0.79', 'estimatedEPS': '0.48', 'surprise': '0.31', 'surprisePercentage': '64.5833'}, {'fiscalDateEnding': '2020-12-31', 'reportedDate': '2021-02-02', 'reportedEPS': '0.71', 'estimatedEPS': '0.36', 'surprise': '0.35', 'surprisePercentage': '97.2222'}, {'fiscalDateEnding': '2020-09-30', 'reportedDate': '2020-10-29', 'reportedEPS': '0.62', 'estimatedEPS': '0.37', 'surprise': '0.25', 'surprisePercentage': '67.5676'}, {'fiscalDateEnding': '2020-06-30', 'reportedDate': '2020-07-30', 'reportedEPS': '0.52', 'estimatedEPS': '0.07', 'surprise': '0.45', 'surprisePercentage': '642.8571'}, {'fiscalDateEnding': '2020-03-31', 'reportedDate': '2020-04-30', 'reportedEPS': '5.01', 'estimatedEPS': '6.25', 'surprise': '-1.24', 'surprisePercentage': '-19.84'}, {'fiscalDateEnding': '2019-12-31', 'reportedDate': '2020-01-30', 'reportedEPS': '6.47', 'estimatedEPS': '4.03', 'surprise': '2.44', 'surprisePercentage': '60.5459'}, {'fiscalDateEnding': '2019-09-30', 'reportedDate': '2019-10-24', 'reportedEPS': '4.23', 'estimatedEPS': '4.62', 'surprise': '-0.39', 'surprisePercentage': '-8.4416'}, {'fiscalDateEnding': '2019-06-30', 'reportedDate': '2019-07-25', 'reportedEPS': '5.22', 'estimatedEPS': '5.57', 'surprise': '-0.35', 'surprisePercentage': '-6.2837'}, {'fiscalDateEnding': '2019-03-31', 'reportedDate': '2019-04-25', 'reportedEPS': '7.09', 'estimatedEPS': '4.72', 'surprise': '2.37', 'surprisePercentage': '50.2119'}, {'fiscalDateEnding': '2018-12-31', 'reportedDate': '2019-01- ...

# %%
import pprint

# pprint.pprint(data)

resultado = pd.DataFrame(data['annualEarnings'])
display(resultado)
# Out:
#    fiscalDateEnding reportedEPS
# 0        2022-06-30       -0.58
# 1        2021-12-31        3.25
# 2        2020-12-31        6.86
# 3        2019-12-31       23.01
# 4        2018-12-31       20.13
# 5        2017-12-31        4.56
# 6        2016-12-31        4.91
# 7        2015-12-31        1.24
# 8        2014-12-31       -0.54
# 9        2013-12-31        0.58
# 10       2012-12-31        0.42
# 11       2011-12-31        1.37
# 12       2010-12-31        2.53
# 13       2009-12-31        2.03
# 14       2008-12-31         1.5
# 15       2007-12-31        1.12
# 16       2006-12-31        0.45
# 17       2005-12-31        0.84
# 18       2004-12-31        0.93
# 19       2003-12-31         0.6
# 20       2002-12-31      0.0776
# 21       2001-12-31       -0.44
# 22       2000-12-31       -1.18
# 23       1999-12-31       -1.17
# 24       1998-12-31       -0.25
# 25       1997-12-31       -0.08
